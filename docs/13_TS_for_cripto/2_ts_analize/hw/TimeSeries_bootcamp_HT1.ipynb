# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании предлагаем вам попрактиковаться в прогнозировании стоимости биткоина при помощи линейной регрессии.

# %%
import pandas as pd
# from matplotlib import pyplot as plt
pd.options.plotting.backend = "plotly"

data = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/BTC_5min_sample.csv",
                   parse_dates=True,
                   index_col='timestamp'
                  )
data.sample(10).T
# Out:
# timestamp  2023-06-25 15:40:00  2023-06-28 13:35:00  2023-06-30 04:55:00  \
# open                30588.8000           30210.6500           31164.5600
# high                30622.0000           30218.0000           31227.0000
# low                 30581.1000           30153.9700           30823.5000
# close               30600.7000           30180.5000           30856.6000
# volume                 19.8156              79.7561             414.3102
#
# timestamp  2023-07-02 06:00:00  2023-06-23 13:00:00  2023-06-22 00:10:00  \
# open                30498.4000            30110.010           29944.0500
# high                30521.0000            30163.000           29982.0000
# low                 30468.2400            30096.900           29887.4000
# close               30497.0000            30147.150           29956.0600
# volume                 20.0235               60.469             106.0309
#
# timestamp  2023-06-27 11:20:00  2023-06-20 02:20:00  2023-06-23 17:05:00  \
# open                30563.3800           26924.5300            31193.520
# high                30599.0000           26960.0000            31217.000
# low                 30536.1000           26898.5000            31062.950
# close               30563.4500           26901.7400            31097.510
# volume                 19.2818              43.0241              159.899
#
# timestamp  2023-06-18 21:25:00
# open                26479.2000
# high                26495.0000
# low                 26430.5800
# close               26440.0000
# volume                 32.2746

# %%
# # import plotly
# import plotly.express as px

# fig = px.line(x=[1,2,3], y=[1,4,9])
# fig.show()

# %% [markdown]
# Будем прогнозировать стоимость биткоина на момент открытия торгов (`open`).

# %%
# data = data[['open']]

# data.plot()
# data['timestamp'].min()
data.plot()
# data.shape

# %% [markdown]
# Проделайте следующие шаги:
#
# * Разбейте данные на тренировочную и тестовую часть. В тест отправьте 15% данных
#
# * Извлеките лаговые признаки
#
# * Извлеките агрегированные признаки (средняя стоимость за день, час)
#
# Рекомендуется использовать функцию preprocess_data с вебинара (однако, надо будет незначительно ее поменять, исходя из данных задачи).
#
# Задайте гиперпараметры по умолчанию (в функции preprocess_data, если будете использовать ее):
# * `lag_start`=5
# * `lag_end`=20
# * `test_size`=0.15

# %%
def code_mean(data, cat_feature, real_feature):
    return dict(data.groupby(cat_feature)[real_feature].mean())

# %%
def preprocess_data(data, lag_start=..., lag_end=..., test_size=...):

    # your code here

    return X_train, X_test, y_train, y_test

# %% [markdown]
# Обучите линейную регрессию с гиперпараметрами по умолчанию на тренировочных данных и вычислите ошибку MAE на тестовых данных.
#
# Чему она получилась равна? (Ответ округлите до целого числа).
#
# Также нарисуйте график правильного ответа и прогноза на тесте.

# %%
# your code here

# %% [markdown]
# Попробуйте подобрать гиперпараметры `lag_start`, `lag_end`, а также придумать новые полезные агрегрированные признаки для улучшения качества прогноза.
#
# Пропорции разбиения (в тесте 15% данных) не трогайте. Ошибку MAE все так же считайте на тесте.

# %%
# your code here
